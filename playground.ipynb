# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# ! pip install pandas_datareader
# ! pip install finance-datareader

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2016, 2, 19)
end = datetime.datetime(2016, 3, 4)
gs = web.DataReader("078930.KS", "yahoo", start, end)

# %%
# KRX는 KOSPI,KOSDAQ,KONEX 모두 포함
# 한국거래소 상장종목 전체
import FinanceDataReader as fdr

df_krx = fdr.StockListing('KRX')

# %%
def get_sym(comName):
    symbol = df_krx[df_krx['Name'] == comName]['Symbol']
    return symbol.iloc[0]

# %%
df = fdr.DataReader('215600', '2018')
df = fdr.DataReader('AAPL', '2018-01-01', '2018-03-30')
df = fdr.DataReader('USD/KRW', '1995')

# %%
df = fdr.DataReader(get_sym('라온피플'),'2017-01-01')

# %%
# Open,High,Low,Close,Volume

# %%
df = df[df.columns[:-1]]

df.columns = ['open','high','log','close','volume']

# %%
sep = int(len(df)*0.7)

# %%
tr = df[:sep]
te = df[sep:]
# Out:
# 235

# %%
df[['open','high','log','close']].plot()
plt.show()
df['volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
